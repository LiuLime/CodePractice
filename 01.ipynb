# %% [markdown]
# <a href="https://colab.research.google.com/github/LiuLime/CodePractice/blob/main/01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook Example

# %%
print("test")
# Out:
# test

# %% [markdown]
# # Check GPU
# 代码执行程序->更改运行时的类型

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## Test save in github
